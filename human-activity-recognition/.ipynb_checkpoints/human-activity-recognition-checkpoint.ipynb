# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# !pip install torch
# !pip install gradio
# Out:
# Requirement already satisfied: torch in c:\users\umair ali\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: filelock in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\umair ali\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\umair ali\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\umair ali\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Collecting gradio
#   Downloading gradio-6.16.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (4.10.0)
# Collecting audioop-lts<=0.2.2 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.136.3-py3-none-any.whl.metadata (27 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (2.3.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (2.12.4)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (0.0.29)
# Requirement already satisfied: pytz>=2017.2 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=1.0.1 (from gradio)
#   Downloading starlette-1.2.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\umair ali\anaconda3\lib\site-packages (from gradio) (0.40.0)
# Requirement already satisfied: fsspec in c:\users\umair ali\anaconda3\lib\site-packages (from gradio-client==2.5.0->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\umair ali\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\umair ali\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\umair ali\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in c:\users\umair ali\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\umair ali\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\umair ali\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Collecting click>=8.4.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\umair ali\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\umair ali\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\umair ali\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\umair ali\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\umair ali\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\umair ali\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.5)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\umair ali\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\umair ali\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: colorama in c:\users\umair ali\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=0.33.5->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\umair ali\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\umair ali\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\umair ali\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\umair ali\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-6.16.0-py3-none-any.whl (20.1 MB)
#    ---------------------------------------- 0.0/20.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/20.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/20.1 MB 1.3 MB/s eta 0:00:16
#    --- ------------------------------------ 1.8/20.1 MB 3.1 MB/s eta 0:00:06
#    -------- ------------------------------- 4.5/20.1 MB 5.6 MB/s eta 0:00:03
#    -------------- ------------------------- 7.1/20.1 MB 7.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.7/20.1 MB 8.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.7/20.1 MB 8.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.9/20.1 MB 5.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.9/20.1 MB 5.6 MB/s eta 0:00:02
#    ------------------ --------------------- 9.2/20.1 MB 4.8 MB/s eta 0:00:03
#    ------------------ --------------------- 9.4/20.1 MB 4.3 MB/s eta 0:00:03
#    ------------------- -------------------- 9.7/20.1 MB 4.1 MB/s eta 0:00:03
#    -------------------- ------------------- 10.2/20.1 MB 3.9 MB/s eta 0:00:03
#    -------------------- ------------------- 10.5/20.1 MB 3.7 MB/s eta 0:00:03
#    --------------------- ------------------ 11.0/20.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 11.3/20.1 MB 3.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 11.8/20.1 MB 3.3 MB/s eta 0:00:03
#    ------------------------ --------------- 12.3/20.1 MB 3.3 MB/s eta 0:00:03
#    ------------------------- -------------- 12.6/20.1 MB 3.2 MB/s eta 0:00:03
#    ------------------------- -------------- 12.8/20.1 MB 3.1 MB/s eta 0:00:03
#    -------------------------- ------------- 13.1/20.1 MB 3.1 MB/s eta 0:00:03
#    -------------------------- ------------- 13.4/20.1 MB 2.9 MB/s eta 0:00:03
#    --------------------------- ------------ 13.6/20.1 MB 2.9 MB/s eta 0:00:03
#    --------------------------- ------------ 13.9/20.1 MB 2.8 MB/s eta 0:00:03
#    --------------------------- ------------ 13.9/20.1 MB 2.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.2/20.1 MB 2.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.2/20.1 MB 2.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.4/20.1 MB 2.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.4/20.1 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.7/20.1 MB 2.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.7/20.1 MB 2.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.9/20.1 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.9/20.1 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 15.2/20.1 MB 2.1 MB/s eta 0:00:03
#    ------------------------------ --------- 15.2/20.1 MB 2.1 MB/s eta 0:00:03
#    ------------------------------- -------- 15.7/20.1 MB 2.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 17.8/20.1 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 19.1/20.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  19.9/20.1 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 20.1/20.1 MB 2.4 MB/s  0:00:08
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading fastapi-0.136.3-py3-none-any.whl (117 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.17.0-py3-none-any.whl (671 kB)
#    ---------------------------------------- 0.0/671.5 kB ? eta -:--:--
#    ---------------------------------------- 671.5/671.5 kB 6.1 MB/s  0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    --------------- ------------------------ 1.6/4.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 10.6 MB/s  0:00:00
# Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl (127 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.2.1-py3-none-any.whl (73 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl (369 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Installing collected packages: pydub, brotli, semantic-version, orjson, hf-xet, groovy, click, audioop-lts, annotated-doc, starlette, safehttpx, fastapi, huggingface-hub, gradio-client, hf-gradio, gradio
#
#    ----- ----------------------------------  2/16 [semantic-version]
#    ------------ ---------------------------  5/16 [groovy]
#   Attempting uninstall: click
#    ------------ ---------------------------  5/16 [groovy]
#     Found existing installation: click 8.2.1
#    ------------ ---------------------------  5/16 [groovy]
#     Uninstalling click-8.2.1:
#    ------------ ---------------------------  5/16 [groovy]
#       Successfully uninstalled click-8.2.1
#    ------------ ---------------------------  5/16 [groovy]
#    --------------- ------------------------  6/16 [click]
#    -------------------- -------------------  8/16 [annotated-doc]
#   Attempting uninstall: starlette
#    -------------------- -------------------  8/16 [annotated-doc]
#     Found existing installation: starlette 0.52.1
#    -------------------- -------------------  8/16 [annotated-doc]
#     Uninstalling starlette-0.52.1:
#    -------------------- -------------------  8/16 [annotated-doc]
#       Successfully uninstalled starlette-0.52.1
#    -------------------- -------------------  8/16 [annotated-doc]
#    ---------------------- -----------------  9/16 [starlette]
#    --------------------------- ------------ 11/16 [fastapi]
#    --------------------------- ------------ 11/16 [fastapi]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    ------------------------------ --------- 12/16 [huggingface-hub]
#    -------------------------------- ------- 13/16 [gradio-client]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ------------------------------------- -- 15/16 [gradio]
#    ---------------------------------------- 16/16 [gradio]
#
# Successfully installed annotated-doc-0.0.4 audioop-lts-0.2.2 brotli-1.2.0 click-8.4.1 fastapi-0.136.3 gradio-6.16.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.5.0 huggingface-hub-1.17.0 orjson-3.11.9 pydub-0.25.1 safehttpx-0.1.7 semantic-version-2.10.0 starlette-1.2.1

# %% [markdown]
# # 1. EDA
# ###  1. Missing values
# ###  2. Class distribution
# ###  3. Outlier detection
# ###  4. Data Encoding
# ###  5. Data Scaling

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train_df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
train_df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
train_df['Activity'].value_counts(normalize=True)*100
# Out:
# Activity
# LAYING                19.137650
# STANDING              18.688792
# SITTING               17.491839
# WALKING               16.675734
# WALKING_UPSTAIRS      14.594668
# WALKING_DOWNSTAIRS    13.411317
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(data=train_df[train_df.columns[:8]], orient='v')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'tBodyAcc-mean()-X'),
#   Text(1, 0, 'tBodyAcc-mean()-Y'),
#   Text(2, 0, 'tBodyAcc-mean()-Z'),
#   Text(3, 0, 'tBodyAcc-std()-X'),
#   Text(4, 0, 'tBodyAcc-std()-Y'),
#   Text(5, 0, 'tBodyAcc-std()-Z'),
#   Text(6, 0, 'tBodyAcc-mad()-X'),
#   Text(7, 0, 'tBodyAcc-mad()-Y')])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y_train_encoded = le.fit_transform(train_df['Activity'])
y_test_encoded = le.transform(test_df['Activity'])

# %%
y_train_encoded
# Out:
# array([2, 2, 2, ..., 5, 5, 5], shape=(7352,))

# %%
train_df['Activity']
# Out:
# 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 7347    WALKING_UPSTAIRS
# 7348    WALKING_UPSTAIRS
# 7349    WALKING_UPSTAIRS
# 7350    WALKING_UPSTAIRS
# 7351    WALKING_UPSTAIRS
# Name: Activity, Length: 7352, dtype: object

# %%
train_df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      7352.000000                      7352.000000
# mean                         -0.307009                        -0.625294
# std                           0.321011                         0.307584
# min                          -0.995357                        -0.999765
# 25%                          -0.542602                        -0.845573
# 50%                          -0.343685                        -0.711692
# 75%                          -0.126979                        -0.503878
# max                           0.989538                         0.956845
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  7352.000000                           7352.000000
# mean                      0.008684                              0.002186
# std                       0.336787                              0.448306
# min                      -0.976580                             -1.000000
# 25%                      -0.121527                             -0.289549
# 50%                       0.009509                              0.008943
# 75%                       0.150865                              0.292861
# max                       1.000000                              1.000000
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       7352.000000                           7352.000000
# mean                           0.008726                             -0.005981
# std                            0.608303                              0.477975
# min                           -1.000000                             -1.000000
# 25%                           -0.482273                             -0.376341
# 50%                            0.008735                             -0.000368
# 75%                            0.506187                              0.359368
# max                            0.998702                              0.996078
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           7352.000000           7352.000000           7352.000000
# mean              -0.489547              0.058593             -0.056515
# std                0.511807              0.297480              0.279122
# min               -1.000000             -1.000000             -1.000000
# 25%               -0.812065             -0.017885             -0.143414
# 50%               -0.709417              0.182071              0.003181
# 75%               -0.509079              0.248353              0.107659
# max                1.000000              0.478157              1.000000
#
#            subject
# count  7352.000000
# mean     17.413085
# std       8.975143
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %% [markdown]
# # 2. Data Preparation

# %%
train_df.shape, test_df.shape
# Out:
# ((7352, 563), (2947, 563))

# %%
train_df['Activity']
# Out:
# 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 7347    WALKING_UPSTAIRS
# 7348    WALKING_UPSTAIRS
# 7349    WALKING_UPSTAIRS
# 7350    WALKING_UPSTAIRS
# 7351    WALKING_UPSTAIRS
# Name: Activity, Length: 7352, dtype: object

# %%
train_df['subject']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 7347    30
# 7348    30
# 7349    30
# 7350    30
# 7351    30
# Name: subject, Length: 7352, dtype: int64

# %%
X_train = train_df.drop(columns=["Activity", "subject"])

X_test = test_df.drop(columns=["Activity", "subject"])

# %%
X_train.shape
# Out:
# (7352, 561)

# %%
import torch

# %%
X_train_tensor = torch.tensor(data=X_train.values, dtype=torch.float32)
X_test_tensor = torch.tensor(data=X_test.values, dtype=torch.float32)

# %%
X_train_tensor.shape
# Out:
# torch.Size([7352, 561])

# %%
y_train_tensor = torch.tensor(data=y_train_encoded, dtype=torch.long)
y_test_tensor = torch.tensor(data=y_test_encoded, dtype=torch.long)

# %%
y_train_tensor.shape
# Out:
# torch.Size([7352])

# %%
from torch.utils.data import TensorDataset

X = torch.tensor([[1,2],
                  [3,4],
                  [5,6]], dtype=torch.float32)

y = torch.tensor([0, 1, 0], dtype=torch.long)

dataset = TensorDataset(X, y)

# %%
dataset[1]
# Out:
# (tensor([3., 4.]), tensor(1))

# %%
X_train_tensor_dataset = TensorDataset(X_train_tensor, y_train_tensor)
X_test_tensor_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
X_train_tensor_dataset[0]
# Out:
# (tensor([ 0.2886, -0.0203, -0.1329, -0.9953, -0.9831, -0.9135, -0.9951, -0.9832,
#          -0.9235, -0.9347, -0.5674, -0.7444,  0.8529,  0.6858,  0.8143, -0.9655,
#          -0.9999, -0.9999, -0.9946, -0.9942, -0.9876, -0.9432, -0.4077, -0.6793,
#          -0.6021,  0.9293, -0.8530,  0.3599, -0.0585,  0.2569, -0.2248,  0.2641,
#          -0.0952,  0.2789, -0.4651,  0.4919, -0.1909,  0.3763,  0.4351,  0.6608,
#           0.9634, -0.1408,  0.1154, -0.9852, -0.9817, -0.8776, -0.9850, -0.9844,
#          -0.8947,  0.8921, -0.1613,  0.1247,  0.9774, -0.1232,  0.0565, -0.3754,
#           0.8995, -0.9709, -0.9755, -0.9843, -0.9888, -0.9177, -1.0000, -1.0000,
#           0.1138, -0.5904,  0.5911, -0.5918,  0.5925, -0.7454,  0.7209, -0.7124,
#           0.7113, -0.9951,  0.9957, -0.9957,  0.9917,  0.5702,  0.4390,  0.9869,
#           0.0780,  0.0050, -0.0678, -0.9935, -0.9884, -0.9936, -0.9945, -0.9862,
#          -0.9928, -0.9852, -0.9920, -0.9931,  0.9898,  0.9920,  0.9905, -0.9935,
#          -0.9999, -0.9998, -0.9999, -0.9944, -0.9860, -0.9892, -0.8199, -0.7930,
#          -0.8889,  1.0000, -0.2207,  0.6368,  0.3876,  0.2414, -0.0523,  0.2642,
#           0.3734,  0.3418, -0.5698,  0.2654, -0.4779, -0.3853,  0.0336, -0.1265,
#          -0.0061, -0.0314,  0.1077, -0.9853, -0.9766, -0.9922, -0.9846, -0.9764,
#          -0.9924, -0.8670, -0.9338, -0.7476,  0.8473,  0.9149,  0.8308, -0.9672,
#          -0.9996, -0.9994, -0.9998, -0.9834, -0.9786, -0.9930,  0.0826,  0.2023,
#          -0.1688,  0.0963, -0.2750,  0.4986, -0.2203,  1.0000, -0.9730,  0.3167,
#           0.3757,  0.7234, -0.7711,  0.6902, -0.3318,  0.7096,  0.1349,  0.3011,
#          -0.0992, -0.0555, -0.0620, -0.9921, -0.9925, -0.9921, -0.9922, -0.9949,
#          -0.9926, -0.9902, -0.9867, -0.9920,  0.9944,  0.9918,  0.9894, -0.9945,
#          -0.9999, -1.0000, -0.9999, -0.9923, -0.9969, -0.9922, -0.5899, -0.6885,
#          -0.5721,  0.2924, -0.3620,  0.4055, -0.0390,  0.9893, -0.4146,  0.3916,
#           0.2823,  0.9273, -0.5724,  0.6916,  0.4683, -0.1311, -0.0872,  0.3362,
#          -0.9594, -0.9506, -0.9580, -0.9463, -0.9926, -0.9594, -0.9985, -0.9576,
#          -0.2326, -0.1732, -0.0229,  0.0948,  0.1918, -0.9594, -0.9506, -0.9580,
#          -0.9463, -0.9926, -0.9594, -0.9985, -0.9576, -0.2326, -0.1732, -0.0229,
#           0.0948,  0.1918, -0.9933, -0.9943, -0.9945, -0.9928, -0.9912, -0.9933,
#          -0.9999, -0.9929, -0.8634,  0.2831, -0.2373, -0.1054, -0.0382, -0.9690,
#          -0.9643, -0.9572, -0.9751, -0.9916, -0.9690, -0.9993, -0.9498,  0.0726,
#           0.5725, -0.7386,  0.2126,  0.4334, -0.9942, -0.9914, -0.9931, -0.9889,
#          -0.9935, -0.9942, -0.9999, -0.9945, -0.6198,  0.2928, -0.1769, -0.1458,
#          -0.1241, -0.9948, -0.9830, -0.9393, -0.9954, -0.9831, -0.9062, -0.9969,
#          -0.9845, -0.9321, -0.9938, -0.9832, -0.8851, -0.9940, -0.9934, -0.9234,
#          -0.9747, -1.0000, -0.9997, -0.9949, -0.9959, -0.9897, -0.9880, -0.9464,
#          -0.9047, -0.5913, -1.0000, -1.0000, -1.0000,  0.2525,  0.1318, -0.0521,
#           0.1421, -0.1507, -0.2205, -0.5587,  0.2468, -0.0074, -1.0000, -1.0000,
#          -1.0000, -1.0000, -0.9999, -0.9997, -0.9997, -1.0000, -1.0000, -1.0000,
#          -0.9999, -0.9998, -1.0000, -0.9999, -0.9997, -0.9999, -0.9999, -0.9999,
#          -0.9997, -0.9997, -0.9995, -0.9998, -0.9997, -0.9998, -0.9997, -0.9996,
#          -0.9997, -0.9998, -0.9936, -0.9995, -0.9997, -0.9996, -0.9993, -0.9979,
#          -0.9959, -0.9951, -0.9947, -0.9997, -0.9989, -0.9957, -0.9949, -0.9995,
#          -0.9923, -0.9872, -0.9897, -0.9958, -0.9909, -0.9971, -0.9938, -0.9905,
#          -0.9970, -0.9967, -0.9920, -0.9932, -0.9983, -0.9911, -0.9599, -0.9905,
#          -0.9999, -0.9998, -0.9999, -0.9930, -0.9914, -0.9962, -1.0000, -1.0000,
#          -1.0000,  1.0000, -0.2400, -1.0000,  0.8704,  0.2107,  0.2637, -0.7037,
#          -0.9037, -0.5826, -0.9363, -0.5073, -0.8055, -1.0000, -1.0000, -1.0000,
#          -1.0000, -0.9999, -0.9996, -0.9995, -1.0000, -1.0000, -1.0000, -0.9998,
#          -0.9995, -1.0000, -0.9999, -0.9999, -0.9999, -0.9998, -0.9999, -0.9997,
#          -0.9997, -0.9996, -0.9998, -0.9999, -0.9998, -0.9997, -0.9996, -0.9999,
#          -0.9998, -0.9994, -0.9998, -1.0000, -0.9999, -0.9998, -0.9998, -0.9988,
#          -0.9986, -0.9996, -1.0000, -0.9998, -0.9987, -0.9998, -0.9999, -0.9866,
#          -0.9818, -0.9895, -0.9850, -0.9739, -0.9940, -0.9865, -0.9836, -0.9924,
#          -0.9805, -0.9723, -0.9949, -0.9976, -0.9841, -0.9943, -0.9853, -0.9999,
#          -0.9997, -0.9999, -0.9903, -0.9948, -0.9944, -0.7124, -0.6448, -0.8390,
#          -1.0000, -1.0000, -1.0000, -0.2575,  0.0979,  0.5472,  0.3773,  0.1341,
#           0.2734, -0.0913, -0.4843, -0.7829, -0.9999, -0.9999, -1.0000, -1.0000,
#          -0.9999, -1.0000, -0.9999, -1.0000, -0.9999, -1.0000, -0.9999, -1.0000,
#          -0.9999, -1.0000, -0.9995, -1.0000, -1.0000, -1.0000, -1.0000, -0.9998,
#          -0.9983, -0.9990, -0.9996, -1.0000, -0.9999, -0.9984, -0.9996, -1.0000,
#          -1.0000, -1.0000, -0.9999, -1.0000, -0.9999, -0.9998, -0.9991, -0.9999,
#          -1.0000, -0.9999, -0.9999, -0.9994, -0.9999, -1.0000, -0.9522, -0.9561,
#          -0.9489, -0.9743, -0.9257, -0.9522, -0.9983, -0.9733, -0.6464, -0.7931,
#          -0.0884, -0.4365, -0.7968, -0.9937, -0.9938, -0.9920, -0.9934, -0.9882,
#          -0.9937, -0.9999, -0.9914, -1.0000, -0.9365,  0.3470, -0.5161, -0.8028,
#          -0.9801, -0.9613, -0.9737, -0.9523, -0.9895, -0.9801, -0.9992, -0.9927,
#          -0.7013, -1.0000, -0.1290,  0.5862,  0.3746, -0.9920, -0.9907, -0.9899,
#          -0.9924, -0.9910, -0.9920, -0.9999, -0.9905, -0.8713, -1.0000, -0.0743,
#          -0.2987, -0.7103, -0.1128,  0.0304, -0.4648, -0.0184, -0.8412,  0.1799,
#          -0.0586]),
#  tensor(2))

# %%
from torch.utils.data import DataLoader

# %%
X_train_dataloader = DataLoader(X_train_tensor_dataset, batch_size=32, shuffle=True, drop_last=True )

# %%
X_test_dataloader = DataLoader(X_test_tensor_dataset, batch_size=32, shuffle=False, drop_last=True )

# %%
X_train_dataloader

# %% [markdown]
# # 3. Model Architecture

# %%
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Linear(561, 50),
    nn.ReLU(),
    nn.Linear(50, 6)
)

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=561, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=6, bias=True)
# )

# %%
model.train()
# Out:
# Sequential(
#   (0): Linear(in_features=561, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=6, bias=True)
# )

# %%
Loss = nn.CrossEntropyLoss()

# %%
import torch.optim as optim

optimiser = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # 4. Model Training

# %%
epochs = 20

for epoch in range(epochs):

    running_loss = 0.0

    for X_batch, y_batch in X_train_dataloader:

        # 1️⃣ Reset gradients
        optimiser.zero_grad()

        # 2️⃣ Forward pass
        outputs = model(X_batch)

        # 3️⃣ Compute loss
        loss = Loss(outputs, y_batch)

        # 4️⃣ Backpropagation
        loss.backward()

        # 5️⃣ Update weights
        optimiser.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(X_train_dataloader)

    print(f"Epoch [{epoch+1}/{epochs}] - Loss: {avg_loss:.4f}")
# Out:
# Epoch [1/20] - Loss: 0.6249
# Epoch [2/20] - Loss: 0.2282
# Epoch [3/20] - Loss: 0.1527
# Epoch [4/20] - Loss: 0.1161
# Epoch [5/20] - Loss: 0.0968
# Epoch [6/20] - Loss: 0.0870
# Epoch [7/20] - Loss: 0.0765
# Epoch [8/20] - Loss: 0.0683
# Epoch [9/20] - Loss: 0.0626
# Epoch [10/20] - Loss: 0.0618
# Epoch [11/20] - Loss: 0.0577
# Epoch [12/20] - Loss: 0.0565
# Epoch [13/20] - Loss: 0.0528
# Epoch [14/20] - Loss: 0.0505
# Epoch [15/20] - Loss: 0.0514
# Epoch [16/20] - Loss: 0.0492
# Epoch [17/20] - Loss: 0.0486
# Epoch [18/20] - Loss: 0.0500
# Epoch [19/20] - Loss: 0.0481
# Epoch [20/20] - Loss: 0.0432

# %% [markdown]
# # 5. Model Evaluation

# %%
model.eval()
# Out:
# Sequential(
#   (0): Linear(in_features=561, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=6, bias=True)
# )

# %%
test_predict = []
test_actual = []

with torch.no_grad():
    for X_batch, y_batch in X_test_dataloader:
        output = model(X_batch)
        max_val, max_val_index = torch.max(output, 1)
        test_predict.extend(max_val_index.numpy())
        test_actual.extend(y_batch.numpy())

# %%
train_predict = []
train_actual = []

with torch.no_grad():
    for X_batch, y_batch in X_train_dataloader:
        output = model(X_batch)
        max_val, max_val_index = torch.max(output, 1)
        train_predict.extend(max_val_index.numpy())
        train_actual.extend(y_batch.numpy())

# %%
from sklearn.metrics import accuracy_score

train_accuracy = accuracy_score(train_actual, train_predict)

# %%
train_accuracy
# Out:
# 0.9848526200873362

# %%
test_accuracy = accuracy_score(test_actual, test_predict)

# %%
test_accuracy
# Out:
# 0.9334239130434783

# %% [markdown]
# # 6. Model Deployment

# %%
import gradio as gr


def predict_activity():
    sample = np.random.randn(561)
    sample = torch.tensor(sample, dtype=torch.float32).unsqueeze(0)

    with torch.no_grad():
        output = model(sample)
        pred = torch.argmax(output, dim=1).item()
        activity = le.inverse_transform([pred])[0]

    return activity

demo = gr.Interface(
    fn=predict_activity,
    inputs=[],
    outputs="text",
    title="Human Activity Recognition (ANN Demo)",
    description="Simulated sensor input → Activity prediction"
)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Missing file: C:\Users\Umair Ali\.cache\huggingface\gradio\frpc\frpc_windows_amd64_v0.3.
#
# Please check your internet connection. This can happen if your antivirus software blocks the download of this file. You can install manually by following these steps:
#
# 1. Download this file: https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_windows_amd64.exe
# 2. Rename the downloaded file to: frpc_windows_amd64_v0.3
# 3. Move the file to this location: C:\Users\Umair Ali\.cache\huggingface\gradio\frpc
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
